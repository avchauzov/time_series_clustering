# %%
import pandas as pd

# %%
data = pd.read_csv('data/updatedData.csv', index_col=None)

# %%
data.head(25)
# Out:
#          Date  108221-10193841  108221-10194165  108221-10194399  \
# 0    1/1/2017              NaN              NaN              NaN
# 1    1/2/2017              NaN              NaN              NaN
# 2    1/3/2017              NaN              NaN              NaN
# 3    1/4/2017              NaN              NaN              NaN
# 4    1/5/2017              NaN              NaN              NaN
# 5    1/6/2017              NaN              NaN              NaN
# 6    1/8/2017              NaN              NaN              NaN
# 7    1/9/2017              NaN              NaN              NaN
# 8   1/10/2017              NaN              NaN              NaN
# 9   1/11/2017              NaN              NaN              NaN
# 10  1/12/2017              NaN              NaN              NaN
# 11  1/13/2017              NaN              NaN              NaN
# 12  1/15/2017              NaN              NaN              NaN
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'], dayfirst = False, yearfirst = False)

# %%
data.head(25)
# Out:
#          Date  108221-10193841  108221-10194165  108221-10194399  \
# 0  2017-01-01              NaN              NaN              NaN
# 1  2017-01-02              NaN              NaN              NaN
# 2  2017-01-03              NaN              NaN              NaN
# 3  2017-01-04              NaN              NaN              NaN
# 4  2017-01-05              NaN              NaN              NaN
# 5  2017-01-06              NaN              NaN              NaN
# 6  2017-01-08              NaN              NaN              NaN
# 7  2017-01-09              NaN              NaN              NaN
# 8  2017-01-10              NaN              NaN              NaN
# 9  2017-01-11              NaN              NaN              NaN
# 10 2017-01-12              NaN              NaN              NaN
# 11 2017-01-13              NaN              NaN              NaN
# 12 2017-01-15              NaN              NaN              NaN
# ...

# %%
data.sort_values('Date', inplace=True)

# %%
data.set_index('Date', inplace=True)

# %%
minDate, maxDate = min(data.index), max(data.index)
data = data.reindex(pd.date_range(start=minDate, end=maxDate))

# %%
# data = data.interpolate(method = 'linear', limit_area = 'inside', inaplce = True)

# %%
data.to_csv('data/1.data.csv')
